# %%
# !pip install opencv-python
import boto3
import cv2
import numpy as np
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from opencv-python) (1.26.4)

# %%
# S3 클라이언트 생성
s3 = boto3.client('s3')

# 버킷 및 폴더 정보
source_bucket = "smwu-cv-data"
source_folder = "data/다이캐스팅/g2/dataset_2023-10-17/NG/5"

# %%
def calculate_white_black_ratio(image_bytes):
    # 이미지 메모리로 로드 (Pillow -> NumPy)
    image = np.array(Image.open(BytesIO(image_bytes)))

    # 전체 픽셀 수
    total_pixels = image.size

    # 흰색 픽셀 개수 (255)
    white_pixels = np.sum(image == 255)

    # 검정색 픽셀 개수 (0)
    black_pixels = np.sum(image == 0)

    # 비율 계산
    white_ratio = white_pixels / total_pixels
    black_ratio = black_pixels / total_pixels

    return white_ratio, black_ratio

# %%
def process_images_and_calculate_ratios():
    # S3에서 이미지 목록 가져오기
    response = s3.list_objects_v2(Bucket=source_bucket, Prefix=source_folder)
    if 'Contents' not in response:
        print("No files found in the source folder.")
        return

    for obj in response['Contents']:
        key = obj['Key']
        if key.endswith(('jpg', 'jpeg', 'png')):  # 이미지 파일만 처리
            print(f"Processing: {key}")

            # S3에서 이미지 다운로드
            file_obj = s3.get_object(Bucket=source_bucket, Key=key)
            image_bytes = file_obj['Body'].read()

            # 흰색 및 검정색 비율 계산
            white_ratio, black_ratio = calculate_white_black_ratio(image_bytes)
            print(f"White Ratio: {white_ratio:.2%}, Black Ratio: {black_ratio:.2%}")

# %%
def calculate_average_ratios():
    white_ratios = []
    black_ratios = []

    # S3에서 이미지 목록 가져오기
    response = s3.list_objects_v2(Bucket=source_bucket, Prefix=source_folder)
    if 'Contents' not in response:
        print("No files found in the source folder.")
        return

    for obj in response['Contents']:
        key = obj['Key']
        if key.endswith(('jpg', 'jpeg', 'png')):  # 이미지 파일만 처리
            print(f"Processing: {key}")

            # S3에서 이미지 다운로드
            file_obj = s3.get_object(Bucket=source_bucket, Key=key)
            image_bytes = file_obj['Body'].read()

            # 흰색 및 검정색 비율 계산
            white_ratio, black_ratio = calculate_white_black_ratio(image_bytes)
            white_ratios.append(white_ratio)
            black_ratios.append(black_ratio)
            print(f"White Ratio: {white_ratio:.2%}, Black Ratio: {black_ratio:.2%}")

    # 평균 계산
    avg_white_ratio = np.mean(white_ratios) if white_ratios else 0
    avg_black_ratio = np.mean(black_ratios) if black_ratios else 0

    print(f"\nAverage White Ratio: {avg_white_ratio:.2%}")
    print(f"Average Black Ratio: {avg_black_ratio:.2%}")
# Out:
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-202550529.png
# White Ratio: 12.69%, Black Ratio: 0.05%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-204503291.png
# White Ratio: 12.57%, Black Ratio: 0.06%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-210609601.png
# White Ratio: 11.22%, Black Ratio: 0.05%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-210630856.png
# White Ratio: 12.39%, Black Ratio: 0.05%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-210652009.png
# White Ratio: 10.19%, Black Ratio: 0.06%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-210713263.png
# White Ratio: 10.79%, Black Ratio: 0.06%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-210734417.png
# White Ratio: 12.21%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013

# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-212806956.png
# White Ratio: 12.19%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-212828411.png
# White Ratio: 10.23%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-212849565.png
# White Ratio: 11.59%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-212910819.png
# White Ratio: 15.97%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-212931972.png
# White Ratio: 14.15%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-212953226.png
# White Ratio: 15.19%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213014380.png
# White Ratio: 11.81%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213035634.png
# White Ratio: 14.08%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213056787.png
# White Ratio: 12.59%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213116732.png
# White Ratio: 14.53%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213136576.png
# White Ratio: 16.95%, Black Ratio: 0.02%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213156521.png
# White Ratio: 12.97%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213216465.png
# White Ratio: 13.94%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213236611.png
# White Ratio: 10.75%, Black Ratio: 0.05%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213256455.png
# White Ratio: 14.44%, Black Ratio: 0.02%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213316601.png
# White Ratio: 11.98%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213336647.png
# White Ratio: 13.65%, Black Ratio: 0.02%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213356590.png
# White Ratio: 13.09%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213416536.png
# White Ratio: 12.52%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213436380.png
# White Ratio: 10.17%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213456325.png
# White Ratio: 13.99%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213516169.png
# White Ratio: 14.07%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213536013.png
# White Ratio: 14.41%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213555857.png
# White Ratio: 11.71%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213615801.png
# White Ratio: 12.55%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213635643.png
# White Ratio: 13.61%, Black Ratio: 0.02%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213655587.png
# White Ratio: 11.60%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213715531.png
# White Ratio: 14.62%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213735475.png
# White Ratio: 14.52%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213755520.png
# White Ratio: 10.44%, Black Ratio: 0.05%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213815364.png
# White Ratio: 13.03%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213835311.png
# White Ratio: 13.36%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213855254.png
# White Ratio: 12.27%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213915199.png
# White Ratio: 10.27%, Black Ratio: 0.05%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213935043.png
# White Ratio: 12.66%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-213954987.png
# White Ratio: 12.33%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214015133.png
# White Ratio: 12.33%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214034976.png
# White Ratio: 14.36%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214054920.png
# White Ratio: 14.72%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214114764.png
# White Ratio: 12.22%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214134608.png
# White Ratio: 13.24%, Black Ratio: 0.04%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214154652.png
# White Ratio: 13.73%, Black Ratio: 0.03%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214220641.png
# White Ratio: 14.41%, Black Ratio: 0.02%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214245521.png
# White Ratio: 9.26%, Black Ratio: 0.06%
# Processing: data/다이캐스팅/g2/dataset_2023-10-17/NG/5/20231013-214311711.png
# White Ratio: 11.41%, Black Ratio: 0.04%
