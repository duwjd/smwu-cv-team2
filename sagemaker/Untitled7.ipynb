# %%
from sagemaker import get_execution_role
print(get_execution_role())
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# arn:aws:iam::730335373015:role/service-role/AmazonSageMaker-ExecutionRole-20240815T144726

# %%
# 노트북 터미널에서 실행
# !zip -r notebook_backup.zip /home/ec2-user/SageMaker/*
# Out:
# 	zip warning: name not matched: /home/ec2-user/SageMaker/wandb/latest-run/logs/debug-core.log
# 	zip warning: name not matched: /home/ec2-user/SageMaker/wandb/run-20241120_104303-f5lowxp3/logs/debug-core.log
# 	zip warning: name not matched: /home/ec2-user/SageMaker/wandb/run-20241120_103537-7alb1q8x/logs/debug-core.log
#   adding: home/ec2-user/SageMaker/2023-09-04-10-10-04-6209_1_00.png (deflated 0%)
#   adding: home/ec2-user/SageMaker/best_model_34_2.pth (deflated 7%)
#   adding: home/ec2-user/SageMaker/best_model_34.pth (deflated 7%)
#   adding: home/ec2-user/SageMaker/best_model_34.tar.gz (deflated 0%)
#   adding: home/ec2-user/SageMaker/best_model_50.pth (deflated 7%)
#   adding: home/ec2-user/SageMaker/best_model_and_script.tar.gz (deflated 0%)
#   adding: home/ec2-user/SageMaker/best_model.keras (deflated 11%)
#   adding: home/ec2-user/SageMaker/best_model.pth (deflated 7%)
#   adding: home/ec2-user/SageMaker/Bring_data.ipynb (deflated 91%)
# ...
